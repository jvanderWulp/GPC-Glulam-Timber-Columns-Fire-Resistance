# %% [markdown]
# # Parametric calculation of fire resistance of GL24h column

# %%
import numpy as np

# %%
import define_bounds as db

# %%
L = 3000       #[mm]
B = 500           # [mm]
F = 1800_000      # [N]

R_1, UC_1 = db.inverse_r_resistance(L, B, F, eta_fi=1.0, e_0=0.02)
print(f'The fire resistance R = {R_1:.2f} min')
print(f'The Unity check UC = {UC_1:.2f}')
# Out:
# The fire resistance R = 149.90 min
# The Unity check UC = 1.00
